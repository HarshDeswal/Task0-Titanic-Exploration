# %%
#importing pandas and numpy libs
import pandas as pd
import numpy as np

# %%
#Collaborating Google colab with drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Loading the Train.csv file of Titanic
D1=pd.read_csv('/content/drive/MyDrive/train.csv')
D1
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
#Removing all the rows having any NULL value
dropnull=D1.dropna()
dropnull
# Out:
#      PassengerId  Survived  Pclass  ...     Fare        Cabin  Embarked
# 1              2         1       1  ...  71.2833          C85         C
# 3              4         1       1  ...  53.1000         C123         S
# 6              7         0       1  ...  51.8625          E46         S
# 10            11         1       3  ...  16.7000           G6         S
# 11            12         1       1  ...  26.5500         C103         S
# ..           ...       ...     ...  ...      ...          ...       ...
# 871          872         1       1  ...  52.5542          D35         S
# 872          873         0       1  ...   5.0000  B51 B53 B55         S
# 879          880         1       1  ...  83.1583          C50         C
# 887          888         1       1  ...  30.0000          B42         S
# 889          890         1       1  ...  30.0000         C148         C
#
# [183 rows x 12 columns]

# %%
#Removing 'Name' and 'PassengerId' column
D1.drop(["Name","PassengerId"],axis=1,inplace=True)
D1
# Out:
#      Survived  Pclass     Sex   Age  ...            Ticket     Fare Cabin  Embarked
# 0           0       3    male  22.0  ...         A/5 21171   7.2500   NaN         S
# 1           1       1  female  38.0  ...          PC 17599  71.2833   C85         C
# 2           1       3  female  26.0  ...  STON/O2. 3101282   7.9250   NaN         S
# 3           1       1  female  35.0  ...            113803  53.1000  C123         S
# 4           0       3    male  35.0  ...            373450   8.0500   NaN         S
# ..        ...     ...     ...   ...  ...               ...      ...   ...       ...
# 886         0       2    male  27.0  ...            211536  13.0000   NaN         S
# 887         1       1  female  19.0  ...            112053  30.0000   B42         S
# 888         0       3  female   NaN  ...        W./C. 6607  23.4500   NaN         S
# 889         1       1    male  26.0  ...            111369  30.0000  C148         C
# ...

# %%
#Dividing Dataset into 80:20 ratio using '.loc'
D1.loc[:713,"Survived":"Embarked"]
# Out:
#      Survived  Pclass     Sex   Age  ...            Ticket     Fare Cabin  Embarked
# 0           0       3    male  22.0  ...         A/5 21171   7.2500   NaN         S
# 1           1       1  female  38.0  ...          PC 17599  71.2833   C85         C
# 2           1       3  female  26.0  ...  STON/O2. 3101282   7.9250   NaN         S
# 3           1       1  female  35.0  ...            113803  53.1000  C123         S
# 4           0       3    male  35.0  ...            373450   8.0500   NaN         S
# ..        ...     ...     ...   ...  ...               ...      ...   ...       ...
# 709         1       3    male   NaN  ...              2661  15.2458   NaN         C
# 710         1       1  female  24.0  ...          PC 17482  49.5042   C90         C
# 711         0       1    male   NaN  ...            113028  26.5500  C124         S
# 712         1       1    male  48.0  ...             19996  52.0000  C126         S
# ...

# %%
#Dividing Dataset into 80:20 ratio using '.iloc'
D1.iloc[714:,0:10]
# Out:
#      Survived  Pclass     Sex   Age  ...      Ticket     Fare  Cabin  Embarked
# 714         0       2    male  52.0  ...      250647   13.000    NaN         S
# 715         0       3    male  19.0  ...      348124    7.650  F G73         S
# 716         1       1  female  38.0  ...    PC 17757  227.525    C45         C
# 717         1       2  female  27.0  ...       34218   10.500   E101         S
# 718         0       3    male   NaN  ...       36568   15.500    NaN         Q
# ..        ...     ...     ...   ...  ...         ...      ...    ...       ...
# 886         0       2    male  27.0  ...      211536   13.000    NaN         S
# 887         1       1  female  19.0  ...      112053   30.000    B42         S
# 888         0       3  female   NaN  ...  W./C. 6607   23.450    NaN         S
# 889         1       1    male  26.0  ...      111369   30.000   C148         C
# 890         0       3    male  32.0  ...      370376    7.750    NaN         Q
#
# [177 rows x 10 columns]

# %%
#Plotting Histogram for 'Fare' and 'Age'
import matplotlib.pyplot as plt
plt.hist(D1['Fare'])
# Out:
# (array([732., 106.,  31.,   2.,  11.,   6.,   0.,   0.,   0.,   3.]),
#  array([  0.     ,  51.23292, 102.46584, 153.69876, 204.93168, 256.1646 ,
#         307.39752, 358.63044, 409.86336, 461.09628, 512.3292 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(D1['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <a list of 10 Patch objects>)

# %%
#Plotting Bar chart for Binary Columns
D1['Survived'].value_counts().head().plot(kind='bar')

# %%
D1['Sex'].value_counts().head().plot(kind='bar')
